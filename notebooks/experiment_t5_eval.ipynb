# %%
# !rm -rf NLP_project
# !git clone https://github.com/lucapl/NLP_project.git
# Out:
# Cloning into 'NLP_project'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 151 (delta 75), reused 127 (delta 52), pack-reused 0
# Receiving objects: 100% (151/151), 31.83 KiB | 15.92 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Cloning into 'NLP_project'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 151 (delta 75), reused 127 (delta 52), pack-reused 0
# Receiving objects: 100% (151/151), 31.83 KiB | 15.92 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
# !pip install -r NLP_project/requirements.txt
# Out:
# Requirement already satisfied: bert-score in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 1)) (0.3.13)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 5)) (4.41.2)
# Requirement already satisfied: py7zr in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 7)) (0.11.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 8)) (4.36.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from -r NLP_project/requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (2.3.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (4.66.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score->-r NLP_project/requirements.txt (line 1)) (24.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score->-r NLP_project/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score->-r NLP_project/requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score->-r NLP_project/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (0.23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->-r NLP_project/requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r NLP_project/requirements.txt (line 5)) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->-r NLP_project/requirements.txt (line 5)) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r NLP_project/requirements.txt (line 5)) (0.4.3)
# Requirement already satisfied: texttable in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (3.20.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr->-r NLP_project/requirements.txt (line 6)) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft->-r NLP_project/requirements.txt (line 7)) (0.31.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.111.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.3.2)
# Requirement already satisfied: gradio-client==1.0.1 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (3.10.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (2.7.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.4.8)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (4.12.1)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (2.0.7)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r NLP_project/requirements.txt (line 8)) (0.30.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.0.1->gradio->-r NLP_project/requirements.txt (line 8)) (11.0.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (3.20.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (2.5.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r NLP_project/requirements.txt (line 9)) (67.7.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->-r NLP_project/requirements.txt (line 8)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r NLP_project/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r NLP_project/requirements.txt (line 3)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r NLP_project/requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r NLP_project/requirements.txt (line 3)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r NLP_project/requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r NLP_project/requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r NLP_project/requirements.txt (line 9)) (4.0.11)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score->-r NLP_project/requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score->-r NLP_project/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score->-r NLP_project/requirements.txt (line 1)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score->-r NLP_project/requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score->-r NLP_project/requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score->-r NLP_project/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score->-r NLP_project/requirements.txt (line 1)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score->-r NLP_project/requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->-r NLP_project/requirements.txt (line 8)) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score->-r NLP_project/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (12.5.40)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->-r NLP_project/requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->-r NLP_project/requirements.txt (line 8)) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->-r NLP_project/requirements.txt (line 8)) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->-r NLP_project/requirements.txt (line 8)) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->-r NLP_project/requirements.txt (line 8)) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->-r NLP_project/requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score->-r NLP_project/requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi->gradio->-r NLP_project/requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r NLP_project/requirements.txt (line 9)) (5.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r NLP_project/requirements.txt (line 8)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r NLP_project/requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r NLP_project/requirements.txt (line 8)) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio->-r NLP_project/requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->-r NLP_project/requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->-r NLP_project/requirements.txt (line 8)) (0.22.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert-score->-r NLP_project/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r NLP_project/requirements.txt (line 8)) (0.1.2)

# %%
# !wandb login

# %%
# !python3 NLP_project/src/experiment_t5_eval.py
# Out:
# 2024-06-12 16:21:54.733269: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-12 16:21:54.800417: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-12 16:21:54.800469: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-12 16:21:54.802265: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-12 16:21:54.810691: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 16:21:55.928402: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: korba-adam (put-cv). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.1
# wandb: Run data is saved locally in /content/wandb/run-20240612_162204-56n2ddk1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run google-t5/t5-small
# wandb: ⭐️ View project at https://wandb.ai/put-cv/NLP_summarization
# wandb: 🚀 View run at https://wandb.ai/put-cv/NLP_summarization/runs/56n2ddk1
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Summarizing 100 docs
# Token indices sequence length is longer than the specified maximum sequence length for this model (755 > 512). Running this sequence through the model will result in indexing errors
# Finished summarizing in 78.57 seconds
# Evaluating predictions using BERTscore (microsoft/deberta-v3-small)
# Evaluated using BERTscore in 2.85 seconds
# Evalyuating predictions using rouge
# Evaluated in 0.08 seconds
# wandb:
# wandb:
# wandb: Run summary:
# wandb:        mean_f1 0.67765
# wandb: mean_precision 0.65402
# wandb:    mean_recall 0.70755
# wandb:    mean_rouge1 0.23115
# wandb:    mean_rouge2 0.06205
# wandb:    mean_rougeL 0.19369
# wandb: mean_rougeLsum 0.19369
# wandb:
# wandb: 🚀 View run google-t5/t5-small at: https://wandb.ai/put-cv/NLP_summarization/runs/56n2ddk1
# wandb: ⭐️ View project at: https://wandb.ai/put-cv/NLP_summarization
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240612_162204-56n2ddk1/logs
# wandb: Tracking run with wandb version 0.17.1
# wandb: Run data is saved locally in /content/wandb/run-20240612_162338-k0d9hqjt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lucapl/t5-summarizer-samsum
# wandb: ⭐️ View project at https://wandb.ai/put-cv/NLP_summarization
# wandb: 🚀 View run at https://wandb.ai/put-cv/NLP_summarization/runs/k0d9hqjt
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Summarizing 100 docs
# Token indices sequence length is longer than the specified maximum sequence length for this model (755 > 512). Running this sequence through the model will result in indexing errors
# Finished summarizing in 54.24 seconds
# Evaluating predictions using BERTscore (microsoft/deberta-v3-small)
# Evaluated using BERTscore in 1.80 seconds
# Evalyuating predictions using rouge
# Evaluated in 0.06 seconds
# wandb:
# wandb:
# wandb: Run summary:
# wandb:        mean_f1 0.80143
# wandb: mean_precision 0.8164
# wandb:    mean_recall 0.78937
# wandb:    mean_rouge1 0.40129
# wandb:    mean_rouge2 0.19066
# wandb:    mean_rougeL 0.34023
# wandb: mean_rougeLsum 0.34023
# wandb:
# wandb: 🚀 View run lucapl/t5-summarizer-samsum at: https://wandb.ai/put-cv/NLP_summarization/runs/k0d9hqjt
# wandb: ⭐️ View project at: https://wandb.ai/put-cv/NLP_summarization
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240612_162338-k0d9hqjt/logs
